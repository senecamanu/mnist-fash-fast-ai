# %%
# !activate tf_gpu

# %%
from __future__ import absolute_import, division, print_function

import tensorflow as tf
from tensorflow import keras as krs
import numpy as np
from matplotlib import pyplot as plt

# %%
fmnist_data = krs.datasets.fashion_mnist

(trainimg, trainlbl), (testimg, testlbl) = fmnist_data.load_data()

# %%
classtitles = [
    'T-shirt/top',
    'Trouser',
    'Pullover',
    'Dress',
    'Coat',
    'Sandal',
    'Shirt',
    'Sneaker',
    'Bag',
    'Ankle Boot'
] # is there a way to load this faster?

# %%
print(trainimg.shape) # single channel
print(testimg.shape) # same, single channel
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
plt.figure()
plt.imshow(trainimg[0], cmap='gray')
plt.colorbar()
plt.grid(False)

plt.show()

# %%
trainimg = trainimg / 255.0
testimg = testimg / 255.0 # only the first 25 images

# %%
print(trainimg.shape)
print(testimg.shape) # shape stays
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
plt.figure()
plt.imshow(trainimg[0], cmap='gray')
plt.colorbar()
plt.grid(False)

plt.show()

# %% [markdown]
# #### Looking above, it shows that the colorbar shows it only scales up from 0 to 1,
# #### with the division of 255 from the second above colorbar max num

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(trainimg[i], cmap='gray')
    plt.xlabel(classtitles[trainlbl[i]])
    
plt.show()

# %% [markdown]
# ### Modelling

# %%
model = krs.Sequential()

# %%
model.add(krs.layers.Flatten(input_shape=(28, 28)))
model.add(krs.layers.Dense(128, activation='relu'))
model.add(krs.layers.Dense(128, activation='relu'))
model.add(krs.layers.Dense(128, activation='relu'))
model.add(krs.layers.Dense(10, activation='softmax')) # based on classtitles list
# Out:
# WARNING:tensorflow:From /root/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
model.fit(trainimg, trainlbl, epochs=10)
# Out:
# Epoch 1/10
# 60000/60000 [==============================] - 7s 111us/sample - loss: 0.4941 - acc: 0.8200
# Epoch 2/10
# 60000/60000 [==============================] - 6s 102us/sample - loss: 0.3647 - acc: 0.8653
# Epoch 3/10
# 60000/60000 [==============================] - 6s 102us/sample - loss: 0.3337 - acc: 0.8776
# Epoch 4/10
# 60000/60000 [==============================] - 6s 102us/sample - loss: 0.3088 - acc: 0.8844
# Epoch 5/10
# 60000/60000 [==============================] - 6s 101us/sample - loss: 0.2921 - acc: 0.8918
# Epoch 6/10
# 60000/60000 [==============================] - 6s 103us/sample - loss: 0.2797 - acc: 0.8949
# Epoch 7/10
# 60000/60000 [==============================] - 6s 104us/sample - loss: 0.2661 - acc: 0.9006
# Epoch 8/10
# 60000/60000 [==============================] - 6s 102us/sample - loss: 0.2563 - acc: 0.9030
# Epoch 9/10
# 60000/60000 [==============================] - 6s 102us/sample - loss: 0.2489 - acc: 0.9058
# Epoch 10/10
# ...

# %% [markdown]
# ### Evaluate Accuracy

# %%
testloss, testacc = model.evaluate(testimg, testlbl)
# Out:
# 10000/10000 [==============================] - 1s 51us/sample - loss: 0.3599 - acc: 0.8726

# %%
print('Test Accuracy:', testacc, 'With test loss:', testloss)
# Out:
# Test Accuracy: 0.8726 With test loss: 0.35993550865650176

# %% [markdown]
# ### Make Predictions

# %%
predictions = model.predict(testimg)

# %%
print(classtitles[np.argmax(predictions[0])])
# Out:
# Ankle Boot

# %%
plt.show(plt.imshow((testimg[0])))
